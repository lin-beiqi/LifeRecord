# %% [markdown]
# When I got up just now, there was a old saying came to my mind "The first dr    um rouses the spirit; the second weakens it; the third exhausts it." So ther    e can not be a second thought of getting up.

# %%
# !date
# Out:
# Sun Dec  7 07:20:22 AM CST 2025

# %% [markdown]
# I did some commit and push operations just now. But I am not quiet familiar with the operations of git, yet. For example, when I finished a ipynb file in local repository, there will be a .ipynb_checkpoints automatic made, which I don't know why it will exit. Then when I did commit operation, I found it. I don't want it... I would definitely figure it out.

# %%
# !date
# Out:
# Sun Dec  7 07:54:54 AM CST 2025
